# %% [markdown]
# ### Train the Model manually (Default ResNet18)

# %%
from src.train import train
train()

# %% [markdown]
# ### Evaluate the Model manually (Default ResNet18)

# %%
from src.evaluate import evaluate
evaluate()

# %% [markdown]
# ### Train the Ensemble

# %%
from src.ensemble import train_ensemble_models
train_ensemble_models()
# Out:
# === Training resnet101 ===
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:21<00:00,  2.11s/it, acc=40.3, loss=1.33]
# Epoch 1: Train Accuracy: 40.31%, Validation Accuracy: 50.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=88.4, loss=0.918]
# Epoch 2: Train Accuracy: 88.44%, Validation Accuracy: 52.50%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=97.2, loss=0.562]
# Epoch 3: Train Accuracy: 97.19%, Validation Accuracy: 60.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=99.1, loss=0.309]
# Epoch 4: Train Accuracy: 99.06%, Validation Accuracy: 67.50%
# ...

# %% [markdown]
# ### Evaluate the Ensemble

# %%
from src.ensemble import evaluate_ensemble
evaluate_ensemble()
# Out:
# Loading resnet101 from /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/results/resnet101_bs32_lr0.0001/best_model.pth
# Loading densenet161_1 from /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/results/densenet161_1_bs32_lr0.0001/best_model.pth
# Loading densenet161_2 from /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/results/densenet161_2_bs32_lr0.0001/best_model.pth
# Evaluating Ensemble on 40 images…
# 100%|██████████| 40/40 [00:04<00:00,  8.67it/s]
# Ensemble Accuracy: 90.00%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.88      0.70      0.78        10
#       InSitu       0.91      1.00      0.95        10
#     Invasive       0.83      1.00      0.91        10
#       Normal       1.00      0.90      0.95        10
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.90      0.90        40
# ...

# %%
# from src.utils import calculate_dataset_stats
# calculate_dataset_stats()

# %% [markdown]
# ---

# %%
from src.ensemble import train_ensemble_models
train_ensemble_models()
# Out:
# === Training resnet18 ===
# Using device: mps
# Training Model: resnet18
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it, acc=50.3, loss=1.09]
# Epoch 1: Train Accuracy: 50.31%, Validation Accuracy: 57.50%
# Saved best model to results/resnet18_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it, acc=93.1, loss=0.303]
# Epoch 2: Train Accuracy: 93.12%, Validation Accuracy: 75.00%
# Saved best model to results/resnet18_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it, acc=99.7, loss=0.116]
# Epoch 3: Train Accuracy: 99.69%, Validation Accuracy: 77.50%
# Saved best model to results/resnet18_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it, acc=100, loss=0.0411]
# Epoch 4: Train Accuracy: 100.00%, Validation Accuracy: 75.00%
# ...

# %%
from src.ensemble import evaluate_ensemble
evaluate_ensemble()
# Out:
# Loading resnet18 from /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/results/resnet18_bs32_lr0.0001/best_model.pth
# Loading densenet121_1 from /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/results/densenet121_1_bs32_lr0.0001/best_model.pth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 from src.ensemble import evaluate_ensemble
# ----> 2 evaluate_ensemble()
#
# File ~/local_documents/semester3/DLMIA/bach_challenge/src/ensemble.py:125, in evaluate_ensemble()
#     122 DEVICE = torch.device("mps" if torch.mps.is_available() else "cpu")
#     124 ensemble_config = config["ensemble2"]["models"]
# --> 125 ensemble = EnsembleClassifier(ensemble_config, DEVICE)
#     127 # load the dataset without transform
#     128 dataset = BachDataset(root_dir=DATA_DIR, transform=None)
#
# ...
