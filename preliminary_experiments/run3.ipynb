# %% [markdown]
# # 1. Running with different Learning Rates
#
# Here I am running each model with augmentation strength of 3 and a 512x512 resolution which proved to be the best in preliminary experiments. This experiment should discover the most suitable learing rate for the specific model(-configuration). Due to the nature of a longer training until convergence for lower learning rates, the epoch number is increased to 20. The analysed learning rates are [0.0001, 0.0005, 0.001].

# %% [markdown]
# ### ResNet101

# %%
from src.train import train

# %%
train(model_name="resnet101", learning_rate=0.0001, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [00:49<00:00,  1.24s/it, acc=50.6, loss=1.23]
# Epoch 1: Train Accuracy: 50.62%, Validation Accuracy: 72.50%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [00:48<00:00,  1.22s/it, acc=71.2, loss=0.829]
# Epoch 2: Train Accuracy: 71.25%, Validation Accuracy: 92.50%
# ...

# %%
train(model_name="resnet101", learning_rate=0.0005, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [00:51<00:00,  1.30s/it, acc=54.4, loss=1.13]
# Epoch 1: Train Accuracy: 54.38%, Validation Accuracy: 72.50%
# Saved best model to results/resnet101_res512_bs8_lr0.0005_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it, acc=68.1, loss=0.864]
# Epoch 2: Train Accuracy: 68.12%, Validation Accuracy: 80.00%
# ...

# %%
train(model_name="resnet101", learning_rate=0.001, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [00:49<00:00,  1.24s/it, acc=42.8, loss=1.29]
# Epoch 1: Train Accuracy: 42.81%, Validation Accuracy: 30.00%
# Saved best model to results/resnet101_res512_bs8_lr0.001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [00:49<00:00,  1.23s/it, acc=42.5, loss=1.25]
# Epoch 2: Train Accuracy: 42.50%, Validation Accuracy: 60.00%
# ...

# %% [markdown]
# ### DenseNet161 (ImageNet)

# %%
train(model_name="densenet161_1", learning_rate=0.0001, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_1
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=56.6, loss=0.997]
# Epoch 1: Train Accuracy: 56.56%, Validation Accuracy: 82.50%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:06<00:00,  1.67s/it, acc=75.9, loss=0.62]
# Epoch 2: Train Accuracy: 75.94%, Validation Accuracy: 80.00%
# ...

# %%
train(model_name="densenet161_1", learning_rate=0.0005, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_1
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:06<00:00,  1.66s/it, acc=49.1, loss=1.22]
# Epoch 1: Train Accuracy: 49.06%, Validation Accuracy: 52.50%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0005_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:06<00:00,  1.66s/it, acc=58.8, loss=1.05]
# Epoch 2: Train Accuracy: 58.75%, Validation Accuracy: 55.00%
# ...

# %%
train(model_name="densenet161_1", learning_rate=0.001, augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_1
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:10<00:00,  1.76s/it, acc=33.8, loss=1.38]
# Epoch 1: Train Accuracy: 33.75%, Validation Accuracy: 42.50%
# Saved best model to results/densenet161_1_res512_bs8_lr0.001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:10<00:00,  1.77s/it, acc=40.9, loss=1.32]
# Epoch 2: Train Accuracy: 40.94%, Validation Accuracy: 45.00%
# ...

# %% [markdown]
# ### DenseNet161 (BACH)

# %%
train(model_name="densenet161_2", learning_rate=0.0001, augmentation_strength=3, normalisation_scheme="bach")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_2
# Normalisation Scheme: bach
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:10<00:00,  1.77s/it, acc=63.4, loss=0.979]
# Epoch 1: Train Accuracy: 63.44%, Validation Accuracy: 85.00%
# Saved best model to results/densenet161_2_res512_bs8_lr0.0001_augm3_normbach/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=80, loss=0.585]
# Epoch 2: Train Accuracy: 80.00%, Validation Accuracy: 77.50%
# ...

# %%
train(model_name="densenet161_2", learning_rate=0.0005, augmentation_strength=3, normalisation_scheme="bach")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_2
# Normalisation Scheme: bach
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:11<00:00,  1.79s/it, acc=44.1, loss=1.33]
# Epoch 1: Train Accuracy: 44.06%, Validation Accuracy: 40.00%
# Saved best model to results/densenet161_2_res512_bs8_lr0.0005_augm3_normbach/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:10<00:00,  1.76s/it, acc=56.9, loss=1.06]
# Epoch 2: Train Accuracy: 56.88%, Validation Accuracy: 60.00%
# ...

# %%
train(model_name="densenet161_2", learning_rate=0.001, augmentation_strength=3, normalisation_scheme="bach")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_2
# Normalisation Scheme: bach
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:14<00:00,  1.85s/it, acc=40.6, loss=1.35]
# Epoch 1: Train Accuracy: 40.62%, Validation Accuracy: 30.00%
# Saved best model to results/densenet161_2_res512_bs8_lr0.001_augm3_normbach/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:11<00:00,  1.79s/it, acc=35.9, loss=1.37]
# Epoch 2: Train Accuracy: 35.94%, Validation Accuracy: 55.00%
# ...
