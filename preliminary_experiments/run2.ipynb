# %% [markdown]
# # 1. Running with 512x512 Resolution
#
# Here I am running each model with a specific augmentation scheme which proved to be the best in preliminary experiments. Using the most advanced augmentation scheme which did not yield the best and most stable validation performance however would probably prove itself the most suitable for real world scenarios in which conditions of scan quality, brightness and staining colourisation vary. Now the input resolution is being analysed. We double each side length from 256 to 512 pixels.

# %% [markdown]
# ### ResNet101

# %%
from src.train import train

# %%
train(model_name="resnet101", augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [00:51<00:00,  1.29s/it, acc=52.2, loss=1.25]
# Epoch 1: Train Accuracy: 52.19%, Validation Accuracy: 70.00%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it, acc=71.6, loss=0.846]
# Epoch 2: Train Accuracy: 71.56%, Validation Accuracy: 85.00%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 3/15: 100%|██████████| 40/40 [00:49<00:00,  1.25s/it, acc=80.3, loss=0.614]
# Epoch 3: Train Accuracy: 80.31%, Validation Accuracy: 80.00%
# Epoch 4/15: 100%|██████████| 40/40 [00:50<00:00,  1.25s/it, acc=85, loss=0.475]
# Epoch 4: Train Accuracy: 85.00%, Validation Accuracy: 90.00%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 5/15: 100%|██████████| 40/40 [00:49<00:00,  1.25s/it, acc=88.1, loss=0.378]
# Epoch 5: Train Accuracy: 88.12%, Validation Accuracy: 92.50%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 6/15: 100%|██████████| 40/40 [00:50<00:00,  1.26s/it, acc=91.2, loss=0.282]
# Epoch 6: Train Accuracy: 91.25%, Validation Accuracy: 95.00%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 7/15: 100%|██████████| 40/40 [00:50<00:00,  1.25s/it, acc=90.9, loss=0.271]
# Epoch 7: Train Accuracy: 90.94%, Validation Accuracy: 92.50%
# Epoch 8/15: 100%|██████████| 40/40 [00:51<00:00,  1.28s/it, acc=89.7, loss=0.309]
# Epoch 8: Train Accuracy: 89.69%, Validation Accuracy: 95.00%
# Epoch 9/15: 100%|██████████| 40/40 [00:52<00:00,  1.31s/it, acc=93.1, loss=0.2]
# Epoch 9: Train Accuracy: 93.12%, Validation Accuracy: 97.50%
# Saved best model to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 10/15: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it, acc=94.1, loss=0.166]
# Epoch 10: Train Accuracy: 94.06%, Validation Accuracy: 92.50%
# Epoch 11/15: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it, acc=93.1, loss=0.18]
# Epoch 11: Train Accuracy: 93.12%, Validation Accuracy: 92.50%
# Epoch 12/15: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it, acc=94.1, loss=0.171]
# Epoch 12: Train Accuracy: 94.06%, Validation Accuracy: 92.50%
# Epoch 13/15: 100%|██████████| 40/40 [00:52<00:00,  1.32s/it, acc=95.9, loss=0.159]
# Epoch 13: Train Accuracy: 95.94%, Validation Accuracy: 92.50%
# Epoch 14/15: 100%|██████████| 40/40 [00:50<00:00,  1.26s/it, acc=95.9, loss=0.131]
# Epoch 14: Train Accuracy: 95.94%, Validation Accuracy: 87.50%
# Epoch 15/15: 100%|██████████| 40/40 [00:50<00:00,  1.27s/it, acc=97.5, loss=0.102]
# Epoch 15: Train Accuracy: 97.50%, Validation Accuracy: 90.00%
#
# --- Saving Metrics ---
# Saved metrics to results/resnet101_res512_bs8_lr0.0001_augm3_normimagenet/metrics.txt
#
# --- Creating history plots ---
# --- Creating confusion matrix ---

# %% [markdown]
# ### DenseNet161 (ImageNet)

# %%
train(model_name="densenet161_1", augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_1
# Normalisation Scheme: imagenet
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:10<00:00,  1.77s/it, acc=57.5, loss=1.04]
# Epoch 1: Train Accuracy: 57.50%, Validation Accuracy: 85.00%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=80, loss=0.652]
# Epoch 2: Train Accuracy: 80.00%, Validation Accuracy: 82.50%
# Epoch 3/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=82.8, loss=0.496]
# Epoch 3: Train Accuracy: 82.81%, Validation Accuracy: 95.00%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 4/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=82.8, loss=0.442]
# Epoch 4: Train Accuracy: 82.81%, Validation Accuracy: 85.00%
# Epoch 5/15: 100%|██████████| 40/40 [01:08<00:00,  1.70s/it, acc=89.4, loss=0.311]
# Epoch 5: Train Accuracy: 89.38%, Validation Accuracy: 95.00%
# Epoch 6/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=87.8, loss=0.35]
# Epoch 6: Train Accuracy: 87.81%, Validation Accuracy: 97.50%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 7/15: 100%|██████████| 40/40 [01:11<00:00,  1.78s/it, acc=94.4, loss=0.217]
# Epoch 7: Train Accuracy: 94.38%, Validation Accuracy: 95.00%
# Epoch 8/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=87.5, loss=0.295]
# Epoch 8: Train Accuracy: 87.50%, Validation Accuracy: 95.00%
# Epoch 9/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=92.2, loss=0.243]
# Epoch 9: Train Accuracy: 92.19%, Validation Accuracy: 97.50%
# Epoch 10/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=96.6, loss=0.14]
# Epoch 10: Train Accuracy: 96.56%, Validation Accuracy: 95.00%
# Epoch 11/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=94.1, loss=0.183]
# Epoch 11: Train Accuracy: 94.06%, Validation Accuracy: 95.00%
# Epoch 12/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=91.2, loss=0.224]
# Epoch 12: Train Accuracy: 91.25%, Validation Accuracy: 97.50%
# Epoch 13/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=97.2, loss=0.135]
# Epoch 13: Train Accuracy: 97.19%, Validation Accuracy: 97.50%
# Epoch 14/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=95.6, loss=0.152]
# Epoch 14: Train Accuracy: 95.62%, Validation Accuracy: 100.00%
# Saved best model to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/best_model.pth
# Epoch 15/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=93.4, loss=0.159]
# Epoch 15: Train Accuracy: 93.44%, Validation Accuracy: 97.50%
#
# --- Saving Metrics ---
# Saved metrics to results/densenet161_1_res512_bs8_lr0.0001_augm3_normimagenet/metrics.txt
#
# --- Creating history plots ---
# --- Creating confusion matrix ---

# %% [markdown]
# ### DenseNet161 (BACH)

# %%
train(model_name="densenet161_2", augmentation_strength=3, normalisation_scheme="bach")
# Out:
# --- Initialising Training Configuration ---
# Using device: mps
# Training Model: densenet161_2
# Normalisation Scheme: bach
#
# --- Loading Dataset and Transforms ---
# Number of Training Samples: 320, Number of Validation Samples: 40
#
# --- Initialising Model ---
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# --- Starting Training Loop ---
# Epoch 1/15: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, acc=55.3, loss=1.06]
# Epoch 1: Train Accuracy: 55.31%, Validation Accuracy: 87.50%
# Saved best model to results/densenet161_2_res512_bs8_lr0.0001_augm3_normbach/best_model.pth
# Epoch 2/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=75.6, loss=0.681]
# Epoch 2: Train Accuracy: 75.62%, Validation Accuracy: 80.00%
# Epoch 3/15: 100%|██████████| 40/40 [01:11<00:00,  1.78s/it, acc=80, loss=0.539]
# Epoch 3: Train Accuracy: 80.00%, Validation Accuracy: 80.00%
# Epoch 4/15: 100%|██████████| 40/40 [01:12<00:00,  1.82s/it, acc=87.5, loss=0.392]
# Epoch 4: Train Accuracy: 87.50%, Validation Accuracy: 80.00%
# Epoch 5/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=88.1, loss=0.405]
# Epoch 5: Train Accuracy: 88.12%, Validation Accuracy: 95.00%
# Saved best model to results/densenet161_2_res512_bs8_lr0.0001_augm3_normbach/best_model.pth
# Epoch 6/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=88.8, loss=0.318]
# Epoch 6: Train Accuracy: 88.75%, Validation Accuracy: 87.50%
# Epoch 7/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=91.6, loss=0.236]
# Epoch 7: Train Accuracy: 91.56%, Validation Accuracy: 95.00%
# Epoch 8/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=91.6, loss=0.228]
# Epoch 8: Train Accuracy: 91.56%, Validation Accuracy: 92.50%
# Epoch 9/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=91.9, loss=0.223]
# Epoch 9: Train Accuracy: 91.88%, Validation Accuracy: 95.00%
# Epoch 10/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=94.1, loss=0.17]
# Epoch 10: Train Accuracy: 94.06%, Validation Accuracy: 90.00%
# Epoch 11/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=95.6, loss=0.189]
# Epoch 11: Train Accuracy: 95.62%, Validation Accuracy: 92.50%
# Epoch 12/15: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, acc=95, loss=0.145]
# Epoch 12: Train Accuracy: 95.00%, Validation Accuracy: 85.00%
# Epoch 13/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=95.9, loss=0.151]
# Epoch 13: Train Accuracy: 95.94%, Validation Accuracy: 100.00%
# Saved best model to results/densenet161_2_res512_bs8_lr0.0001_augm3_normbach/best_model.pth
# Epoch 14/15: 100%|██████████| 40/40 [01:08<00:00,  1.72s/it, acc=96.2, loss=0.14]
# Epoch 14: Train Accuracy: 96.25%, Validation Accuracy: 95.00%
# Epoch 15/15: 100%|██████████| 40/40 [01:09<00:00,  1.73s/it, acc=95.6, loss=0.17]
# Epoch 15: Train Accuracy: 95.62%, Validation Accuracy: 95.00%
#
# --- Saving Metrics ---
# Saved metrics to results/densenet161_2_res512_bs8_lr0.0001_augm3_normbach/metrics.txt
#
# --- Creating history plots ---
# --- Creating confusion matrix ---
