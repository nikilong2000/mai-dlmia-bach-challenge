# %% [markdown]
# # 1. Running with different Augmentation Schemes
#
# Here I am running each model manually with each augmentation scheme. That makes **3** models (ResNet101, DenseNet161 (ImageNet normalisation) and DenseNet161 (BACH normalisation)) x **4** augmentation schemes (no augmentation, simple geometric, complex geometric) == 12 overall results.

# %% [markdown]
# ### ResNet101

# %%
from src.train import train

# %%
from src.train import train
train(model_name="resnet101", augmentation_strength=0, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:22<00:00,  2.22s/it, acc=42.5, loss=1.34]
# Epoch 1: Train Accuracy: 42.50%, Validation Accuracy: 52.50%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:21<00:00,  2.16s/it, acc=90, loss=0.917]
# Epoch 2: Train Accuracy: 90.00%, Validation Accuracy: 70.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it, acc=96.6, loss=0.545]
# Epoch 3: Train Accuracy: 96.56%, Validation Accuracy: 80.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:21<00:00,  2.15s/it, acc=98.1, loss=0.28]
# Epoch 4: Train Accuracy: 98.12%, Validation Accuracy: 90.00%
# ...

# %%
train(model_name="resnet101", augmentation_strength=1, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:21<00:00,  2.16s/it, acc=37.2, loss=1.33]
# Epoch 1: Train Accuracy: 37.19%, Validation Accuracy: 50.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:22<00:00,  2.21s/it, acc=74.4, loss=1.08]
# Epoch 2: Train Accuracy: 74.38%, Validation Accuracy: 65.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:21<00:00,  2.11s/it, acc=80, loss=0.821]
# Epoch 3: Train Accuracy: 80.00%, Validation Accuracy: 72.50%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=86.6, loss=0.581]
# Epoch 4: Train Accuracy: 86.56%, Validation Accuracy: 77.50%
# ...

# %%
train(model_name="resnet101", augmentation_strength=2, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/15: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it, acc=42.8, loss=1.31]
# Epoch 1: Train Accuracy: 42.81%, Validation Accuracy: 67.50%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=67.8, loss=1.1]
# Epoch 2: Train Accuracy: 67.81%, Validation Accuracy: 70.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it, acc=75.9, loss=0.849]
# ...

# %%
train(model_name="resnet101", augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: resnet101
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/15: 100%|██████████| 10/10 [00:23<00:00,  2.34s/it, acc=37.5, loss=1.35]
# Epoch 1: Train Accuracy: 37.50%, Validation Accuracy: 42.50%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it, acc=68.4, loss=1.14]
# Epoch 2: Train Accuracy: 68.44%, Validation Accuracy: 65.00%
# Saved best model to results/resnet101_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:22<00:00,  2.27s/it, acc=74.4, loss=0.929]
# ...

# %% [markdown]
# ### DenseNet161 (ImageNet)

# %%
train(model_name="densenet161_1", augmentation_strength=0, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:27<00:00,  2.77s/it, acc=58.8, loss=1.09]
# Epoch 1: Train Accuracy: 58.75%, Validation Accuracy: 72.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:26<00:00,  2.67s/it, acc=94.4, loss=0.357]
# Epoch 2: Train Accuracy: 94.38%, Validation Accuracy: 82.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.60s/it, acc=99.1, loss=0.142]
# Epoch 3: Train Accuracy: 99.06%, Validation Accuracy: 90.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:25<00:00,  2.59s/it, acc=100, loss=0.0486]
# Epoch 4: Train Accuracy: 100.00%, Validation Accuracy: 90.00%
# ...

# %%
train(model_name="densenet161_1", augmentation_strength=1, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:27<00:00,  2.71s/it, acc=55, loss=1.14]
# Epoch 1: Train Accuracy: 55.00%, Validation Accuracy: 72.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:27<00:00,  2.75s/it, acc=82.5, loss=0.578]
# Epoch 2: Train Accuracy: 82.50%, Validation Accuracy: 85.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.68s/it, acc=93.4, loss=0.304]
# Epoch 3: Train Accuracy: 93.44%, Validation Accuracy: 90.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:26<00:00,  2.66s/it, acc=97.2, loss=0.177]
# Epoch 4: Train Accuracy: 97.19%, Validation Accuracy: 95.00%
# ...

# %%
train(model_name="densenet161_1", augmentation_strength=2, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:26<00:00,  2.68s/it, acc=51.9, loss=1.15]
# Epoch 1: Train Accuracy: 51.88%, Validation Accuracy: 72.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:26<00:00,  2.66s/it, acc=77.8, loss=0.673]
# Epoch 2: Train Accuracy: 77.81%, Validation Accuracy: 82.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.61s/it, acc=88.4, loss=0.421]
# Epoch 3: Train Accuracy: 88.44%, Validation Accuracy: 85.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:27<00:00,  2.70s/it, acc=92.8, loss=0.28]
# Epoch 4: Train Accuracy: 92.81%, Validation Accuracy: 90.00%
# ...

# %%
train(model_name="densenet161_1", augmentation_strength=3, normalisation_scheme="imagenet")
# Out:
# Using device: mps
# Training Model: densenet161_1
# Normalisation Scheme: imagenet
# Number of Training Samples: 320, Number of Validation Samples: 40
# /Users/niklaslongschiefelbein/local_documents/semester3/DLMIA/bach_challenge/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:132: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/15: 100%|██████████| 10/10 [00:28<00:00,  2.90s/it, acc=55.6, loss=1.13]
# Epoch 1: Train Accuracy: 55.62%, Validation Accuracy: 70.00%
# Saved best model to results/densenet161_1_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:26<00:00,  2.62s/it, acc=80.3, loss=0.635]
# Epoch 2: Train Accuracy: 80.31%, Validation Accuracy: 75.00%
# Saved best model to results/densenet161_1_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:27<00:00,  2.73s/it, acc=87.5, loss=0.435]
# ...

# %% [markdown]
# ### DenseNet161 (BACH)

# %%
train(model_name="densenet161_2", augmentation_strength=0, normalisation_scheme="bach")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: bach
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:26<00:00,  2.70s/it, acc=53.8, loss=1.11]
# Epoch 1: Train Accuracy: 53.75%, Validation Accuracy: 80.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:26<00:00,  2.62s/it, acc=90, loss=0.446]
# Epoch 2: Train Accuracy: 90.00%, Validation Accuracy: 82.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.67s/it, acc=98.4, loss=0.18]
# Epoch 3: Train Accuracy: 98.44%, Validation Accuracy: 85.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:28<00:00,  2.81s/it, acc=99.7, loss=0.0735]
# Epoch 4: Train Accuracy: 99.69%, Validation Accuracy: 87.50%
# ...

# %%
train(model_name="densenet161_2", augmentation_strength=1, normalisation_scheme="bach")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: bach
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:28<00:00,  2.81s/it, acc=55.6, loss=1.11]
# Epoch 1: Train Accuracy: 55.62%, Validation Accuracy: 67.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:26<00:00,  2.67s/it, acc=81.9, loss=0.584]
# Epoch 2: Train Accuracy: 81.88%, Validation Accuracy: 80.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.62s/it, acc=92.2, loss=0.307]
# Epoch 3: Train Accuracy: 92.19%, Validation Accuracy: 90.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:25<00:00,  2.59s/it, acc=96.6, loss=0.185]
# Epoch 4: Train Accuracy: 96.56%, Validation Accuracy: 95.00%
# ...

# %%
train(model_name="densenet161_2", augmentation_strength=2, normalisation_scheme="bach")
# Out:
# Using device: mps
# Training Model: densenet161
# Normalisation Scheme: bach
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:26<00:00,  2.67s/it, acc=53.1, loss=1.17]
# Epoch 1: Train Accuracy: 53.12%, Validation Accuracy: 77.50%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:27<00:00,  2.79s/it, acc=81.9, loss=0.632]
# Epoch 2: Train Accuracy: 81.88%, Validation Accuracy: 77.50%
# Epoch 3/15: 100%|██████████| 10/10 [00:26<00:00,  2.69s/it, acc=88.1, loss=0.398]
# Epoch 3: Train Accuracy: 88.12%, Validation Accuracy: 90.00%
# Saved best model to results/densenet161_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:26<00:00,  2.64s/it, acc=91.9, loss=0.26]
# Epoch 4: Train Accuracy: 91.88%, Validation Accuracy: 87.50%
# Epoch 5/15: 100%|██████████| 10/10 [00:26<00:00,  2.65s/it, acc=95.3, loss=0.192]
# ...

# %%
train(model_name="densenet161_2", augmentation_strength=3, normalisation_scheme="bach")
# Out:
# Using device: mps
# Training Model: densenet161_2
# Normalisation Scheme: bach
# Number of Training Samples: 320, Number of Validation Samples: 40
# Epoch 1/15: 100%|██████████| 10/10 [00:28<00:00,  2.87s/it, acc=50.9, loss=1.16]
# Epoch 1: Train Accuracy: 50.94%, Validation Accuracy: 72.50%
# Saved best model to results/densenet161_2_bs32_lr0.0001/best_model.pth
# Epoch 2/15: 100%|██████████| 10/10 [00:25<00:00,  2.59s/it, acc=82.5, loss=0.639]
# Epoch 2: Train Accuracy: 82.50%, Validation Accuracy: 80.00%
# Saved best model to results/densenet161_2_bs32_lr0.0001/best_model.pth
# Epoch 3/15: 100%|██████████| 10/10 [00:25<00:00,  2.57s/it, acc=83.8, loss=0.461]
# Epoch 3: Train Accuracy: 83.75%, Validation Accuracy: 87.50%
# Saved best model to results/densenet161_2_bs32_lr0.0001/best_model.pth
# Epoch 4/15: 100%|██████████| 10/10 [00:27<00:00,  2.70s/it, acc=91.9, loss=0.282]
# Epoch 4: Train Accuracy: 91.88%, Validation Accuracy: 90.00%
# ...
